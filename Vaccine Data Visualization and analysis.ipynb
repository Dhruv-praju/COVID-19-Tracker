# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
vac_data = pd.read_csv('cleaned_vaccinations.csv')

# %%
pd.set_option('display.max_rows', 2000)

# %%
vac_data.head(1000)
# Out:
#                  country        date  total_vaccinations  \
# 0            Afghanistan  2021-02-22                   0
# 1            Afghanistan  2021-02-23                   0
# 2            Afghanistan  2021-02-24                   0
# 3            Afghanistan  2021-02-25                   0
# 4            Afghanistan  2021-02-26                   0
# 5            Afghanistan  2021-02-27                   0
# 6            Afghanistan  2021-02-28                8200
# 7            Afghanistan  2021-03-01                8200
# 8            Afghanistan  2021-03-02                8200
# 9            Afghanistan  2021-03-03                8200
# 10           Afghanistan  2021-03-04                8200
# 11           Afghanistan  2021-03-05                8200
# 12           Afghanistan  2021-03-06                8200
# 13           Afghanistan  2021-03-07                8200
# 14           Afghanistan  2021-03-08                8200
# ...

# %%
vac_data.dtypes
# Out:
# country                               object
# date                                  object
# total_vaccinations                     int64
# people_vaccinated_only_1st_dose        int64
# people_fully_vaccinated                int64
# daily_vaccinations                     int64
# daily_vaccinations_avgd                int64
# %_people_vaccinated                  float64
# %_people_vaccinated_only_1st_dose    float64
# %_people_fully_vaccinated            float64
# vaccines                              object
# dtype: object

# %%
vac_data['date'] = pd.to_datetime(vac_data['date'], format='%Y-%m-%d')

# %%
vac_data.dtypes
# Out:
# country                                      object
# date                                 datetime64[ns]
# total_vaccinations                            int64
# people_vaccinated_only_1st_dose               int64
# people_fully_vaccinated                       int64
# daily_vaccinations                            int64
# daily_vaccinations_avgd                       int64
# %_people_vaccinated                         float64
# %_people_vaccinated_only_1st_dose           float64
# %_people_fully_vaccinated                   float64
# vaccines                                     object
# dtype: object

# %% [markdown]
# # 2) Data Visualization

# %%
plt.style.use('seaborn')
filt = vac_data.country=='Gibralter'
vac_data.loc[filt]
# Out:
# Empty DataFrame
# Columns: [country, date, total_vaccinations, people_vaccinated_only_1st_dose, people_fully_vaccinated, daily_vaccinations, daily_vaccinations_avgd, %_people_vaccinated, %_people_vaccinated_only_1st_dose, %_people_fully_vaccinated, vaccines]
# Index: []

# %% [markdown]
#     Countrywise data

# %%
country_grp = vac_data.groupby(['country'])

# %%
country_grp['total_vaccinations']

# %%
con_wise_df = country_grp.agg({'total_vaccinations': 'max',
                 'people_vaccinated_only_1st_dose':'max',
                 'people_fully_vaccinated':'max',
                 'daily_vaccinations_avgd':'median',
                 '%_people_vaccinated':'max'})

# %%
con_wise_df
# Out:
#                                   total_vaccinations  \
# country
# Afghanistan                                    54000
# Albania                                       232379
# Algeria                                        75000
# Andorra                                        12440
# Angola                                        181578
# Anguilla                                        5348
# Antigua and Barbuda                            26424
# Argentina                                    4571819
# Armenia                                          565
# Australia                                     920334
# Austria                                      1872531
# Azerbaijan                                   1025790
# Bahamas                                         7000
# Bahrain                                       879825
# Bangladesh                                   5568703
# Barbados                                       63738
# ...

# %%
con_wise_df
# Out:
#                                   total_vaccinations  \
# country
# Afghanistan                                    54000
# Albania                                       232379
# Algeria                                        75000
# Andorra                                        12440
# Angola                                        181578
# Anguilla                                        5348
# Antigua and Barbuda                            26424
# Argentina                                    4571819
# Armenia                                          565
# Australia                                     920334
# Austria                                      1872531
# Azerbaijan                                   1025790
# Bahamas                                         7000
# Bahrain                                       879825
# Bangladesh                                   5568703
# Barbados                                       63738
# ...

# %%
con_wise_total_vac = con_wise_df['total_vaccinations'].sort_values(ascending=False).head(20)
con_wise_total_vac
# Out:
# country
# United States           171476655
# China                   149071000
# India                    90198673
# United Kingdom           37391103
# Brazil                   24197996
# Turkey                   17704888
# Germany                  15427516
# Indonesia                13452610
# Russia                   13047800
# France                   12789529
# Italy                    11738824
# Chile                    11396072
# Israel                   10189198
# Mexico                   10089420
# Spain                     9357847
# United Arab Emirates      8707073
# Morocco                   8448106
# Poland                    6999652
# Canada                    6990144
# Bangladesh                5568703
# Name: total_vaccinations, dtype: int64

# %%
con_wise_total_vac.sort_values(ascending=True, inplace=True)

# %% [markdown]
# ## What country have vaccinated more people ?

# %%
con_wise_total_vac.plot(kind='barh', figsize=(10,8))

# plt.barh(con_wise_total_vac.index, con_wise_total_vac.values)
plt.ylabel('Conutry',fontsize=14)
plt.xlabel('Total Vaccinations',fontsize=14)
plt.yticks(fontsize=13)
plt.xticks(fontsize=13)
plt.suptitle('Total Vaccinations by Country', fontsize=20)
# Out:
# Text(0.5, 0.98, 'Total Vaccinations by Country')

# %% [markdown]
# `United States has Vaccinated most number of people`
#
# `USA and China were worst hit by the pandemic and we can see that now they are leading in terms of vaccination administered i.e. people who have atleast received first dose`
#
# `From above bar plot USA, China and India have done mass vaccination`

# %% [markdown]
# ### Country wise people fully vaccinated

# %%
con_wise_full_vac = con_wise_df['people_fully_vaccinated'].sort_values(ascending=False).head(20)

# %%
help(pd.Series.plot)
# Out:
# Help on class PlotAccessor in module pandas.plotting._core:
#
# class PlotAccessor(pandas.core.base.PandasObject)
#  |  PlotAccessor(data)
#  |
#  |  Make plots of Series or DataFrame.
#  |
#  |  Uses the backend specified by the
#  |  option ``plotting.backend``. By default, matplotlib is used.
#  |
#  |  Parameters
#  |  ----------
#  |  data : Series or DataFrame
#  |      The object for which the method is called.
#  |  x : label or position, default None
#  |      Only used if data is a DataFrame.
#  |  y : label, position or list of label, positions, default None
#  |      Allows plotting of one column versus another. Only used if data is a
#  |      DataFrame.
#  |  kind : str
#  |      The kind of plot to produce:
#  |
#  |      - 'line' : line plot (default)
#  |      - 'bar' : vertical bar plot
#  |      - 'barh' : horizontal bar plot
#  |      - 'hist' : histogram
#  |      - 'box' : boxplot
#  |      - 'kde' : Kernel Density Estimation plot
# ...

# %%
con_wise_full_vac.plot(kind='bar',figsize=(10,6))
plt.xlabel('Conutry',fontsize=14)
plt.ylabel('Fully Vaccinated',fontsize=14)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.suptitle('People Fully Vaccinated by Country', fontsize=20)
# Out:
# Text(0.5, 0.98, 'People Fully Vaccinated by Country')

# %% [markdown]
# `Maximum number of people are given both the doses(1st and 2nd) in United States, followed by India and Turkey`

# %% [markdown]
# ## How many COVID-19 vaccines doses are administered daily ?

# %% [markdown]
# ## Which countries have vaccinated more people per day ?

# %%
con_wise_daily_vac = con_wise_df['daily_vaccinations_avgd'].sort_values(ascending=False).head(20)

# %%
con_wise_daily_vac.plot(kind='bar',figsize=(10,6))

plt.xlabel('Conutry',fontsize=14)
plt.ylabel('Median Daily Vaccinations',fontsize=14)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.suptitle('Average Daily Vaccination by Country', fontsize=20)
# Out:
# Text(0.5, 0.98, 'Average Daily Vaccination by Country')

# %% [markdown]
# `We can see that USA, China and India and UK has immunized good amount of people on daily basis. Out of which US has highest numbers`

# %% [markdown]
# ## What country is vaccinated a larger percentage of its population ?

# %% [markdown]
# ### "What share of the population has received at least one dose of the COVID-19 vaccine?"

# %% [markdown]
# ### "What share of the population has been fully vaccinated against COVID-19?"

# %%
con_max_pop_vac = con_wise_df['%_people_vaccinated'].sort_values(ascending=False).head(20)

# %%
con_max_pop_vac.plot(kind='bar', figsize=(10,6))
plt.xlabel('Conutry',fontsize=14)
plt.ylabel('Percent(%)',fontsize=14)
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.suptitle('Percent of Population Vaccinated by Country', fontsize=20)
# Out:
# Text(0.5, 0.98, 'Percent of Population Vaccinated by Country')

# %% [markdown]
# `From above plot we can see, Although USA has vaccinated much larger people, it has not vaccinated largest percent of population`
#
# `We can say that Gilbratar, Israel and UAE have almost completely vaccinated their country`

# %%
con_wise_full_half_vac = con_wise_df.sort_values(by=['total_vaccinations'],
                                                ascending=False)[['people_fully_vaccinated',
                                                                 'people_vaccinated_only_1st_dose']].head(40)
con_wise_full_half_vac
# Out:
#                       people_fully_vaccinated  people_vaccinated_only_1st_dose
# country
# United States                        61480921                        109995734
# China                                       0                        149071000
# India                                11435646                         78763027
# United Kingdom                        5683509                         31707594
# Brazil                                5338722                         18859274
# Turkey                                7345498                         10359390
# Germany                               4633839                         10793677
# Indonesia                             4431504                          9021106
# Russia                                5138882                          7908918
# France                                3227796                          9561733
# Italy                                 3616215                          8122609
# ...

# %%
con_wise_full_half_vac.plot.bar(stacked=True, figsize=(13,6))
plt.legend(['Fully vaccinated','Atleat one dose'])
# plt.yscale('log')
plt.xlabel('Conutry',fontsize=15)
plt.ylabel('Count',fontsize=14)
plt.xticks(fontsize=11)
plt.yticks(fontsize=11)
plt.suptitle('Share of Full and half vaccinated', fontsize=20)
# Out:
# Text(0.5, 0.98, 'Share of Full and half vaccinated')

# %% [markdown]
# ## What country has advance and good vaccination program ?

# %% [markdown]
# ## After the beginning of the vaccine process all around the world, how the infection trend moves?
