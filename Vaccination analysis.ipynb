# %% [markdown]
# # 1) Data Cleaning

# %%
import pandas as pd
import numpy as np

# %%
vac_data = pd.read_csv('country_vaccinations.csv')
vac_data
# Out:
#           country iso_code        date  total_vaccinations  people_vaccinated  \
# 0     Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1     Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2     Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3     Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4     Afghanistan      AFG  2021-02-26                 NaN                NaN
# ...           ...      ...         ...                 ...                ...
# 7332     Zimbabwe      ZWE  2021-03-15             37660.0            37660.0
# 7333     Zimbabwe      ZWE  2021-03-16             39550.0            39550.0
# 7334     Zimbabwe      ZWE  2021-03-17             39607.0            39607.0
# 7335     Zimbabwe      ZWE  2021-03-18             40002.0            40002.0
# 7336     Zimbabwe      ZWE  2021-03-19             41687.0            41687.0
#
# ...

# %%
vac_data.tail(60)
# Out:
#        country  iso_code        date  total_vaccinations  people_vaccinated  \
# 7277     Wales  OWID_WLS  2021-02-17            841975.0           822633.0
# 7278     Wales  OWID_WLS  2021-02-18            864498.0           839065.0
# 7279     Wales  OWID_WLS  2021-02-19            885906.0           853904.0
# 7280     Wales  OWID_WLS  2021-02-20            897856.0           860083.0
# 7281     Wales  OWID_WLS  2021-02-21            905000.0           862248.0
# 7282     Wales  OWID_WLS  2021-02-22            919382.0           869653.0
# 7283     Wales  OWID_WLS  2021-02-23            937785.0           878506.0
# 7284     Wales  OWID_WLS  2021-02-24            959121.0           889270.0
# 7285     Wales  OWID_WLS  2021-02-25            982396.0           902334.0
# 7286     Wales  OWID_WLS  2021-02-26           1005389.0           916336.0
# 7287     Wales  OWID_WLS  2021-02-27           1020023.0           923615.0
# ...

# %%
vac_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7337 entries, 0 to 7336
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              7337 non-null   object
#  1   iso_code                             7337 non-null   object
#  2   date                                 7337 non-null   object
#  3   total_vaccinations                   4552 non-null   float64
#  4   people_vaccinated                    4053 non-null   float64
#  5   people_fully_vaccinated              2749 non-null   float64
#  6   daily_vaccinations_raw               3830 non-null   float64
#  7   daily_vaccinations                   7150 non-null   float64
#  8   total_vaccinations_per_hundred       4552 non-null   float64
#  9   people_vaccinated_per_hundred        4053 non-null   float64
#  10  people_fully_vaccinated_per_hundred  2749 non-null   float64
# ...

# %%
# Drop all columns that we don't want
vac_data.drop(['iso_code', 'daily_vaccinations_per_million', 'source_name', 'source_website','daily_vaccinations'], axis=1, inplace=True)

# %%
vac_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7337 entries, 0 to 7336
# Data columns (total 10 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              7337 non-null   object
#  1   date                                 7337 non-null   object
#  2   total_vaccinations                   4552 non-null   float64
#  3   people_vaccinated                    4053 non-null   float64
#  4   people_fully_vaccinated              2749 non-null   float64
#  5   daily_vaccinations_raw               3830 non-null   float64
#  6   total_vaccinations_per_hundred       4552 non-null   float64
#  7   people_vaccinated_per_hundred        4053 non-null   float64
#  8   people_fully_vaccinated_per_hundred  2749 non-null   float64
#  9   vaccines                             7337 non-null   object
# dtypes: float64(7), object(3)
# memory usage: 573.3+ KB

# %%
pd.set_option('display.max_rows', 100)
vac_data
# Out:
#           country        date  total_vaccinations  people_vaccinated  \
# 0     Afghanistan  2021-02-22                 0.0                0.0
# 1     Afghanistan  2021-02-23                 NaN                NaN
# 2     Afghanistan  2021-02-24                 NaN                NaN
# 3     Afghanistan  2021-02-25                 NaN                NaN
# 4     Afghanistan  2021-02-26                 NaN                NaN
# ...           ...         ...                 ...                ...
# 7332     Zimbabwe  2021-03-15             37660.0            37660.0
# 7333     Zimbabwe  2021-03-16             39550.0            39550.0
# 7334     Zimbabwe  2021-03-17             39607.0            39607.0
# 7335     Zimbabwe  2021-03-18             40002.0            40002.0
# 7336     Zimbabwe  2021-03-19             41687.0            41687.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  \
# 0                         NaN                     NaN
# ...

# %% [markdown]
# ### Rename columns

# %%
vac_data.rename(columns = {'people_vaccinated':'people_only_1st_dose',
                           'people_fully_vaccinated':'people_2nd_dose',
                           'daily_vaccinations_raw':'daily_vaccinations',
                           'total_vaccinations_per_hundred':'%_people_vaccinated',
                           'people_vaccinated_per_hundred':'%_people_only_1st_dose',
                           'people_fully_vaccinated_per_hundred':'%_people_2nd_dose'}, inplace=True)

# %%
vac_data
# Out:
#           country        date  total_vaccinations  people_only_1st_dose  \
# 0     Afghanistan  2021-02-22                 0.0                   0.0
# 1     Afghanistan  2021-02-23                 NaN                   NaN
# 2     Afghanistan  2021-02-24                 NaN                   NaN
# 3     Afghanistan  2021-02-25                 NaN                   NaN
# 4     Afghanistan  2021-02-26                 NaN                   NaN
# ...           ...         ...                 ...                   ...
# 7332     Zimbabwe  2021-03-15             37660.0               37660.0
# 7333     Zimbabwe  2021-03-16             39550.0               39550.0
# 7334     Zimbabwe  2021-03-17             39607.0               39607.0
# 7335     Zimbabwe  2021-03-18             40002.0               40002.0
# 7336     Zimbabwe  2021-03-19             41687.0               41687.0
#
#       people_2nd_dose  daily_vaccinations  %_people_vaccinated  \
# ...

# %%
vac_data.shape
# Out:
# (7337, 10)

# %%
vac_data.country.describe()
# Out:
# count       7337
# unique       150
# top       Canada
# freq          96
# Name: country, dtype: object

# %% [markdown]
#     See for missing values

# %% [markdown]
# Percentage of missing values

# %%
total_mis_val = vac_data.isnull().sum().sum()
total_mis_val
# Out:
# 24821

# %%
total_cells = np.product(vac_data.shape)
total_cells
# Out:
# 73370

# %%
per_missing_val = (total_mis_val / total_cells) * 100
per_missing_val
# Out:
# 33.82990323020308

# %% [markdown]
# >34 % of the data from our dataset is empty
